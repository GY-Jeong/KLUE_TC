# %%
cur_dir = '/content/drive/MyDrive/KLUE_TC/data/open/'

# %%
import pandas as pd
from tqdm import tqdm

# %%
dacon_train_data = pd.read_csv(cur_dir + 'train_data_translated.csv')
dacon_topic_data = pd.read_csv(cur_dir + 'topic_dict.csv')
dacon_test_data = pd.read_csv(cur_dir + 'test_data_translated.csv')

titles = list(dacon_train_data['title'])

# %%
import os
import sys
import urllib.request
import json
client_id = "EcVqBHWpR_3pMxOYrfWj" # 개발자센터에서 발급받은 Client ID 값
client_secret = "P33PEkEkD9" # 개발자센터에서 발급받은 Client Secret 값

# %%
urls = []
original_urls = []

for title in tqdm(titles[:24500]):
    encText = urllib.parse.quote(title)
    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_body = json.loads(response_body)
        if response_body['total'] == 0:
            urls.append("")
            original_urls.append("")
        else:
            urls.append(response_body["items"][0]["link"])
            original_urls.append(response_body["items"][0]["originallink"])
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
# Out:
#  67%|██████▋   | 16416/24500 [3:48:21<1:53:29,  1.19it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-8b14327c10d9> in <module>()
#       8     request.add_header("X-Naver-Client-Id",client_id)
#       9     request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 10     response = urllib.request.urlopen(request)
#      11     rescode = response.getcode()
#      12     if(rescode==200):
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
def writeDict(file_name, dictionary):
    with open(file_name, 'w', encoding='utf-8') as file:
        for data in dictionary:
            file.write(data + '\n')

# %%
writeDict('/content/drive/MyDrive/KLUE_TC/data/urls.txt', urls)
writeDict('/content/drive/MyDrive/KLUE_TC/data/original_urls.txt', original_urls)

# %%
urls

# %%
# !pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 211 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 87 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 7.4 MB 14.5 MB/s
# ...
#      |████████████████████████████████| 81 kB 7.9 MB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13551 sha256=0169e6690ea5530af6d3fff6324b08b30cb8b2b18392171fc09c15ac6ca60c2c
#   Stored in directory: /root/.cache/pip/wheels/df/67/41/faca10fa501ca010be41b49d40360c2959e1c4f09bcbfa37fa
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3354 sha256=1ea7a4aa8b64122d1ebc3ff0c5bdaa777c700dca126f2521dc26efb3e76b8729
#   Stored in directory: /root/.cache/pip/wheels/7f/d4/8f/6e2ca54744c9d7292d88ddb8d42876bcdab5e6d84a21c10346
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398404 sha256=2cfa1ee34eb8e85cbb7574385761bcb313625391e53d93e40d52c2cc433b2286
# ...

# %%
import newspaper

# %%
from newspaper import Article

# %%
news_url = 'http://www.ytn.co.kr/_ln/0103_201608080700372202'
article = Article(news_url, language='ko')

# %%
article.download()
article.parse()

print('title:', article.title)
print('context:', article.text)
# Out:
# title: 핀란드행 항공기 결항...휴가철 여행객 분통
# context: 인천국제공항을 출발해 핀란드로 향할 여객기가 결항이 되면서, 승객들이 하루가 넘도록 불편을 겪어야 했습니다.
#
#
#
# 인천국제공항공사는 지난 6일 오전 10시 10분 승객 200여 명을 태우고 핀란드 헬싱키로 가려던 핀에어 여객기가 정비 문제로 결항했다고 밝혔습니다.
#
#
#
# 이에 항공사 측은 공항 인근 숙소를 제공했지만, 계획에 차질이 생긴 승객들은 분통을 터뜨렸습니다.
#
#
#
# 대체 항공편은 다음날인 어제(7일) 오후 3시 반이 돼서야 제공됐고, 북유럽 패키지 여행객 26명은 공항에 남아 항의를 이어갔습니다.
#
# [저작권자(c) YTN & YTN plus 무단전재 및 재배포 금지]
